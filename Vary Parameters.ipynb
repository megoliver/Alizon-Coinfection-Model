# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# %matplotlib inline

from sympy.solvers import solve
from sympy import Symbol

# %%
def resident(x, t):
    lamda = (beta1*(x[1]+x[2]))
    sdot = rho - mu*x[0] - sigmaS*lamda*x[0]
    i1dot = sigmaS*lamda*x[0] - (mu+alpha1+(sigmaI*lamda))*x[1]
    d11dot = sigmaI*lamda*x[1] - (mu+alpha1)*x[2]
    return sdot,i1dot,d11dot

# %%
tmax2 = 2000
ts2 = np.linspace(0,200,tmax2)

# %%
rho = 0.02                              # host input function
mu = 0.02                               # basline mortality rate
sigmaS = 1                            # vulnerability of suscpetible hosts to infection
sigmaI = 5                            # vulnerability of infected hosts to infection
alpha1 = 0.03                           # virulence of a host infected by 1
beta1 = 0.4                          # transmission rate of strain 1 in single infection

# %% [markdown]
# # Vary $\beta_1$

# %%
beta1_values = np.arange(start=0, stop=1.2, step=0.2)

# %%
for i in range(6):
    beta1 = beta1_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    Ss = xs[:,0]
   
    plt.plot(ts2,Ss)

plt.legend([r'$\beta_1=0$',r'$\beta_1=0.2$',r'$\beta_1=0.4$',r'$\beta_1=0.6$',r'$\beta_1=0.8$',r'$\beta_1=1$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %%
for i in range(6):
    beta1 = beta1_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    I1s = xs[:,1]
   
    plt.plot(ts2,I1s)

plt.legend([r'$\beta_1=0$',r'$\beta_1=0.2$',r'$\beta_1=0.4$',r'$\beta_1=0.6$',r'$\beta_1=0.8$',r'$\beta_1=1$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %%
for i in range(6):
    beta1 = beta1_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    D11s = xs[:,2]
   
    plt.plot(ts2,D11s)

plt.legend([r'$\beta_1=0$',r'$\beta_1=0.2$',r'$\beta_1=0.4$',r'$\beta_1=0.6$',r'$\beta_1=0.8$',r'$\beta_1=1$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %% [markdown]
# # Vary $\alpha_1$

# %%
beta1 = 0.4                          # transmission rate of strain 1 in single infection

# %%
alpha1_values = np.arange(start=0, stop=0.24, step=0.04)

# %%
for i in range(6):
    alpha1 = alpha1_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    Ss = xs[:,0]
   
    plt.plot(ts2,Ss)

plt.legend([r'$\alpha_1=0$',r'$\alpha_1=0.04$',r'$\alpha_1=0.08$',r'$\alpha_1=0.12$',r'$\alpha_1=0.16$',r'$\alpha_1=0.2$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %%
for i in range(6):
    alpha1 = alpha1_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    I1s = xs[:,1]
   
    plt.plot(ts2,I1s)

plt.legend([r'$\alpha_1=0$',r'$\alpha_1=0.04$',r'$\alpha_1=0.08$',r'$\alpha_1=0.12$',r'$\alpha_1=0.16$',r'$\alpha_1=0.2$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %%
for i in range(6):
    alpha1 = alpha1_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    D11s = xs[:,2]
   
    plt.plot(ts2,D11s)

plt.legend([r'$\alpha_1=0$',r'$\alpha_1=0.04$',r'$\alpha_1=0.08$',r'$\alpha_1=0.12$',r'$\alpha_1=0.16$',r'$\alpha_1=0.2$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %% [markdown]
# # Vary $\sigma_S$

# %%
alpha1 = 0.03                           # virulence of a host infected by 1

# %%
SigmaS_values = np.arange(start=0, stop=3.5, step=0.5)

# %%
for i in range(6):
    sigmaS = SigmaS_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    Ss = xs[:,0]
   
    plt.plot(ts2,Ss)

plt.legend([r'$\sigma_S=0$',r'$\sigma_S=0.5$',r'$\sigma_S=1$',r'$\sigma_S=1.5$',r'$\sigma_S=2$',r'$\sigma_S=2.5$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %%
for i in range(6):
    sigmaS = SigmaS_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    I1s = xs[:,1]
   
    plt.plot(ts2,I1s)

plt.legend([r'$\sigma_S=0$',r'$\sigma_S=0.5$',r'$\sigma_S=1$',r'$\sigma_S=1.5$',r'$\sigma_S=2$',r'$\sigma_S=2.5$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %% [markdown]
# ### Magnify

# %%
for i in range(6):
    sigmaS = SigmaS_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    I1s = xs[:,1]
   
    plt.plot(ts2,I1s)

plt.legend([r'$\sigma_S=0$',r'$\sigma_S=0.5$',r'$\sigma_S=1$',r'$\sigma_S=1.5$',r'$\sigma_S=2$',r'$\sigma_S=2.5$'],  loc='upper center')    
plt.xlim(175,200)
plt.ylim(0,0.1)
plt.show()

# %%
for i in range(6):
    sigmaS = SigmaS_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    D11s = xs[:,2]
   
    plt.plot(ts2,D11s)

plt.legend([r'$\sigma_S=0$',r'$\sigma_S=0.5$',r'$\sigma_S=1$',r'$\sigma_S=1.5$',r'$\sigma_S=2$',r'$\sigma_S=2.5$'],  loc='upper center')    
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %% [markdown]
# ### Magnify

# %%
for i in range(6):
    sigmaS = SigmaS_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    D11s = xs[:,2]
   
    plt.plot(ts2,D11s)

plt.legend([r'$\sigma_S=0$',r'$\sigma_S=0.5$',r'$\sigma_S=1$',r'$\sigma_S=1.5$',r'$\sigma_S=2$',r'$\sigma_S=2.5$'],  loc='upper center')
plt.xlim(175,200)
plt.ylim(0,0.5)
plt.show()

# %% [markdown]
# # Vary $\sigma_I$

# %%
sigmaS = 1                            # vulnerability of suscpetible hosts to infection

# %%
SigmaI_values = np.arange(start=0, stop=3.5, step=0.5)

# %%
for i in range(6):
    sigmaI = SigmaI_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    Ss = xs[:,0]
   
    plt.plot(ts2,Ss)

plt.legend([r'$\sigma_I=0$',r'$\sigma_I=0.5$',r'$\sigma_I=1$',r'$\sigma_I=1.5$',r'$\sigma_I=2$',r'$\sigma_I=2.5$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %%
for i in range(6):
    sigmaI = SigmaI_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    I1s = xs[:,1]
   
    plt.plot(ts2,I1s)
    
plt.legend([r'$\sigma_I=0$',r'$\sigma_I=0.5$',r'$\sigma_I=1$',r'$\sigma_I=1.5$',r'$\sigma_I=2$',r'$\sigma_I=2.5$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %%
for i in range(6):
    sigmaI = SigmaI_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    D11s = xs[:,2]
   
    plt.plot(ts2,D11s)

plt.legend([r'$\sigma_I=0$',r'$\sigma_I=0.5$',r'$\sigma_I=1$',r'$\sigma_I=1.5$',r'$\sigma_I=2$',r'$\sigma_I=2.5$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %% [markdown]
# # Vary $\mu$

# %%
sigmaI = 5                            # vulnerability of infected hosts to infection

# %%
mu_values = np.arange(start=0, stop=0.12, step=0.02)

# %%
for i in range(6):
    mu = mu_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    Ss = xs[:,0]
   
    plt.plot(ts2,Ss)

plt.legend([r'$\mu=0$',r'$\mu=0.02$',r'$\mu=0.04$',r'$\mu=0.06$',r'$\mu=0.08$',r'$\mu=1$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %%
for i in range(6):
    mu = mu_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    I1s = xs[:,1]
   
    plt.plot(ts2,I1s)

plt.legend([r'$\mu=0$',r'$\mu=0.02$',r'$\mu=0.04$',r'$\mu=0.06$',r'$\mu=0.08$',r'$\mu=1$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %% [markdown]
# ### Magnify

# %%
for i in range(6):
    mu = mu_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    I1s = xs[:,1]
   
    plt.plot(ts2,I1s)

plt.legend([r'$\mu=0$',r'$\mu=0.02$',r'$\mu=0.04$',r'$\mu=0.06$',r'$\mu=0.08$',r'$\mu=1$'],  loc='upper center')
plt.xlim(175,200)
plt.ylim(0,0.1)
plt.show()

# %%
for i in range(6):
    mu = mu_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    D11s = xs[:,2]
   
    plt.plot(ts2,D11s)

plt.legend([r'$\mu=0$',r'$\mu=0.02$',r'$\mu=0.04$',r'$\mu=0.06$',r'$\mu=0.08$',r'$\mu=1$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %% [markdown]
# # Vary $\rho$

# %%
mu = 0.02                               # basline mortality rate

# %%
rho_values = np.arange(start=0, stop=0.12, step=0.02)

# %%
for i in range(6):
    rho = rho_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    Ss = xs[:,0]
   
    plt.plot(ts2,Ss)

plt.legend([r'$\rho=0$',r'$\rho=0.02$',r'$\rho=0.04$',r'$\rho=0.06$',r'$\rho=0.08$',r'$\rho=1$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %%
for i in range(6):
    rho = rho_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    I1s = xs[:,1]
   
    plt.plot(ts2,I1s)

plt.legend([r'$\rho=0$',r'$\rho=0.02$',r'$\rho=0.04$',r'$\rho=0.06$',r'$\rho=0.08$',r'$\rho=1$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()

# %%
for i in range(6):
    rho = rho_values[i]
    
    x0 = [0.8,0.5,0.05]
    xs = odeint(resident,x0,ts2)

    D11s = xs[:,2]
   
    plt.plot(ts2,D11s)

plt.legend([r'$\rho=0$',r'$\rho=0.02$',r'$\rho=0.04$',r'$\rho=0.06$',r'$\rho=0.08$',r'$\rho=1$'],  loc='upper center')
plt.xlim(0,200)
plt.ylim(0)
plt.show()
