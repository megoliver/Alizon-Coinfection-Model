# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# %matplotlib inline

from sympy.solvers import solve
from sympy import Symbol

# %%
def resident(x, t):
    lamda = (beta1*(x[1]+x[2]))
    sdot = rho - mu*x[0] - sigmaS*lamda*x[0]
    i1dot = sigmaS*lamda*x[0] - (mu+alpha1+(sigmaI*lamda))*x[1]
    d11dot = sigmaI*lamda*x[1] - (mu+alpha1)*x[2]
    return sdot,i1dot,d11dot

# %%
rho = 0.02                              # host input function
mu = 0.02                               # basline mortality rate
sigmaS = 1                            # vulnerability of suscpetible hosts to infection
sigmaI = 5                            # vulnerability of infected hosts to infection
alpha1 = 0.03                           # virulence of a host infected by 1
beta1 = 0.4                          # transmission rate of strain 1 in single infection

# %%
tmax2 = 2000
ts2 = np.linspace(0,200,tmax2)

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)

Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

### S, I & D coexist for these parameter values

# %%
Ss
# Out:
# array([0.8       , 0.78276372, 0.76548638, ..., 0.12500026, 0.12500026,
#        0.12500026])

# %%
I1s
# Out:
# array([0.5       , 0.4616557 , 0.42635588, ..., 0.02333339, 0.02333339,
#        0.02333339])

# %%
D11s
# Out:
# array([0.05      , 0.10320947, 0.15337567, ..., 0.32666595, 0.32666596,
#        0.32666596])

# %%
rho = 0.01                              # host input function
mu = 0.075                               # basline mortality rate
sigmaS = 1                            # vulnerability of suscpetible hosts to infection
sigmaI = 5                            # vulnerability of infected hosts to infection
alpha1 = 0.04                           # virulence of a host infected by 1
beta1 = 0.4                          # transmission rate of strain 1 in single infection

# %%
tmax2 = 2000
ts2 = np.linspace(0,200,tmax2)

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)

Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

### S, I & D coexist for these parameter values

# %%
Ss
# Out:
# array([0.8       , 0.77754507, 0.75541558, ..., 0.13332855, 0.13332857,
#        0.1333286 ])

# %%
I1s
# Out:
# array([5.00000000e-01, 4.58772509e-01, 4.21245799e-01, ...,
#        1.28937463e-06, 1.28141659e-06, 1.27350659e-06])

# %%
D11s
# Out:
# array([5.00000000e-02, 1.02371826e-01, 1.50758116e-01, ...,
#        7.10680011e-10, 7.33769654e-10, 7.57387475e-10])

# %%
#rho = 0.01                           # host input function
#mu = 0.06                           # basline mortality rate
#sigmaS = 7                            # vulnerability of suscpetible hosts to infection
#sigmaI = 1                            # vulnerability of infected hosts to infection
#alpha1 = 0.05                          # virulence of a host infected by 1
#beta1 = 0.2                          # transmission rate of strain 1 in single infection

# %%
#rho = 0.02                           # host input function
#mu = 0.08                           # basline mortality rate
#sigmaS = 7                            # vulnerability of suscpetible hosts to infection
#sigmaI = 1                            # vulnerability of infected hosts to infection
#alpha1 = 0.05                          # virulence of a host infected by 1
#beta1 = 0.2                          # transmission rate of strain 1 in single infection

# %%
rho = 0.015                              # host input function
mu = 0.05                               # basline mortality rate
sigmaS = 5                            # vulnerability of suscpetible hosts to infection
sigmaI = 0.01                            # vulnerability of infected hosts to infection
alpha1 = 0.05                           # virulence of a host infected by 1
beta1 = 0.25                          # transmission rate of strain 1 in single infection

# %%
tmax2 = 2000
ts2 = np.linspace(0,200,tmax2)

# %%
x0 = [0.8,0.5,0.05]
xs = odeint(resident,x0,ts2)

Ss = xs[:,0]
I1s = xs[:,1]
D11s = xs[:,2]

# %%
# Time Course
plt.plot(ts2,Ss)
plt.plot(ts2,I1s)
plt.plot(ts2,D11s)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Numbers', fontsize=14)
plt.xlim((0,200))
plt.ylim((0))
plt.legend(['S', r'$I_1$', r'$D_{11}$'], loc='upper right')
plt.show()

### S, I & D coexist for these parameter values

# %%
Ss
# Out:
# array([0.8       , 0.74223681, 0.68449371, ..., 0.08      , 0.08      ,
#        0.08      ])

# %%
I1s
# Out:
# array([0.5       , 0.55007782, 0.59991003, ..., 0.10969833, 0.10969833,
#        0.10969833])

# %%
D11s
# Out:
# array([0.05      , 0.04957742, 0.0491733 , ..., 0.00030167, 0.00030167,
#        0.00030167])
